# %%
from __future__ import division, print_function
import numpy as np
import matplotlib.pyplot as plt
import skdemo
% matplotlib inline
# Out:
# UsageError: Line magic function `%` not found.

# %%
from skimage import data

# %%
import matplotlib.pyplot as plt

from skimage import io, color
from PIL import Image
from skimage.restoration import denoise_tv_chambolle
from skimage.restoration import denoise_bilateral

# img1 = io.imread('./Fig/MEL.jpg')
img1 = Image.open('./Fig/MEL.jpg').resize((800,600))
img2 = Image.open('./Fig/NV.jpg').resize((800,600))
img3 = Image.open('./Fig/BCC.jpg').resize((800,600))
img4 = Image.open('./Fig/AK.jpg').resize((800,600))
img5 = Image.open('./Fig/BKL.jpg').resize((800,600))
img6 = Image.open('./Fig/DF.jpg').resize((800,600))
img7 = Image.open('./Fig/VASC.jpg').resize((800,600))
img8 = Image.open('./Fig/SCC.jpg').resize((800,600))
img9 = Image.open('./Fig/emptyWhite.jpg').resize((800,600))


# img9=img9.resize((800,800))

fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(8, 8), sharex=True,
                       sharey=True)

plt.gray()

# ax[0, 0].imshow(img1)
# ax[0, 0].axis('off')
# ax[0, 0].set_title('a) Melanoma')
#
# ax[0, 1].imshow(img2)
# ax[0, 1].axis('off')
# ax[0, 1].set_title('b) Melanocytic nevus')

ax[0, 0].imshow(img3)
ax[0, 0].axis('off')
ax[0, 0].set_title('e) Basal cell carcinoma', fontdict={'weight':'normal','size': 15})

ax[0, 1].imshow(img4)
ax[0, 1].axis('off')
ax[0, 1].set_title('f) Actinic keratosis', fontdict={'weight':'normal','size': 15})

ax[1, 0].imshow(img5)
ax[1, 0].axis('off')
ax[1, 0].set_title('g) Benign keratosis', fontdict={'weight':'normal','size': 15})

ax[1, 1].imshow(img6)
ax[1, 1].axis('off')
ax[1, 1].set_title('h) Dermatofibroma', fontdict={'weight':'normal','size': 15})

# ax[1, 0].imshow(img7)
# ax[1, 0].axis('off')
# ax[1, 0].set_title('c) Vascular lesion')
#
# ax[1, 1].imshow(img8)
# ax[1, 1].axis('off')
# ax[1, 1].set_title('d) Squamous cell carcinoma')

# ax[1, 1].imshow(img9)
# ax[1, 1].axis('off')
# ax[1, 1].set_title('Unknown')

fig.tight_layout()

plt.savefig('./Fig/Image.jpg')
plt.show()
